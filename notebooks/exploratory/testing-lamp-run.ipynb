# %%
#!/usr/bin/env python
# coding: utf-8

# # Code to run electon density -> energy inversion as per Semeter, Kamalabadi 2005 for PFISR data for specified number of days
# 
# written by Riley Troyer Fall 2021

# In[1]:


# Libraries
import datetime
from datetime import datetime as dt
import gc
import h5py
from matplotlib import pyplot as plt
from matplotlib import colors
import msise00
import numpy as np
import os
import pickle
import scipy.stats
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter
from scipy.signal import savgol_coeffs
from scipy.integrate import trapezoid

# This might set off some warnings, but I think they can be ignored
from kaeppler_chemistry import Chemistry as chemistry

# Disable divide by zero numpy warnings
np.seterr(divide='ignore')
np.seterr(invalid='ignore')
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %%
# In[2]:


# Read in config file with dictionary of specified inputs
import config_2022_05_25 as config
config_data = config.run_info['config_info']

# Path to pfisr data directory
pfisr_data_dir = config_data['isr_data_dir']

# File with times for events of interest
reference_file = config_data['event_file']

# Directory to save files to
save_dir = config_data['save_dir']

# Get location of PFISR
pfrr_lat = config_data['isr_lat']
pfrr_lon = config_data['isr_lon']

# Define test flux in m^-2 s^-1
F = config_data['test_flux']

# Don't use PFISR data below this altitude in km
pfisr_min_alt = config_data['isr_min_alt']

# Get sensitivity limit of PFISR
pfisr_sensitivity = config_data['isr_sensitivity']

# Altitude in meters to approximate infinity when calculating
#...mass distance
max_msis_alt = config_data['max_msis_alt']

# Maximum number of iterations to run maximum entropy process on
max_iterations = config_data['max_iterations']

# Reduced chi square to aim for
convergence = config_data['convergence']

# Define arrays for altitude and energy bins

# Altitude in meters
#...number of points should be around the same as pfisr data
altitude_bins = config_data['altitude_bins']

# Energies in eV
#...should probably be less than altitude bins to avoid overfitting
energy_bins = config_data['energy_bins']

# Get which chemistry model to use
alpha_type = config_data['alpha_type']

# Get files to run code for
pfisr_files = config.run_info['run_files']

pfisr_files = ['20220305.001_bc_nenotr_1min.h5']#pfisr_files[43:]

# %%
# In[3]:


def barrett_hays_range_energy_func(K):
    """Function to define mass range of electron in air for a specific
    energy K in eV. From Barett & Hays 1976
    INPUT
    K
        type: float
        about: energy of electron in eV
    OUTPUT
    R
        type: float
        about: mass range of particle in kg m^-2 
    """
    # Convert energy to keV to match formula
    K = K/1000
    
    # Range function
    R = 4.3e-7 + 5.36e-6 * K**(1.67) - 0.38e-8 * K**(-0.7)
    
    # Convert R from g/cm^2 to kg/m^2
    R = R * 10
    
    return R

def estimate_initial_number_flux(energy_bins, matrix_A):
    """Function to estimate the intial number flux for each energy bin
    INPUT
    energy_bins
        type: array of float
        about: energy values defining energy bins
    matrix_A
        type: array of float
        about: inversion matrix
    OUTPUT
    initial_num_flux
        type: array of float
        about: estimated number flux in m^-2 s^-1 for each energy bin
    """
    
    # Make an initial guess of the number flux
    initial_num_flux = np.ones(len(energy_bins))*(1e12/len(energy_bins))

    # Divide by energy bin widths
    bin_widths = energy_bins - np.roll(energy_bins, shift=1)

    # Fix first value
    bin_widths[0] = energy_bins[0] - 0

    # Set initial guess
    initial_num_flux = initial_num_flux/bin_widths

    # If full column of A matrix is zero set initial flux to zero
    for j in range(len(energy_bins)):

        if np.sum(matrix_A[:, j]) == 0:
            initial_num_flux[j] = 0
            
    return initial_num_flux

def find_event_indices(utc_time):
    """Function to find only indices of times of interest.
    INPUT
    utc_time
        type: array of datetimes
        about: utc datetimes of all pfisr data
    OUTPUT
    slices_n
        type: list of integers
        about: indices of pfisr data that is of interest
    """
    
    # Find the date for the current pfisr file, this is a little tricky as
    #...some pfisr files span multiple days
    pfisr_dates = np.unique(np.array([d.date() for d in utc_time]))

    # Dates that are in both pa database and pfisr file
    pa_pfisr_dates = np.unique(np.array([d for d in pa_dates 
                                         if d in pfisr_dates]))

    # Loop through each of these dates and get correct indices
    indices = []
    for date in pa_pfisr_dates:
            indices.append(np.argwhere(pa_dates == date))

    # Flatten list of indices
    indices = [item[0] for sublist in indices for item in sublist]

    # Loop through each index and get data slices corresponding to the
    #...start and stop times
    slices_n = []
    for index in indices:

        # Get the date and start time of measurements
        date = pa_database[index, 0]
        start_time = date + ' ' + pa_database[index, 1]
        end_time = date + ' ' + pa_database[index, 2]

        # Convert to datetime
        start_time = dt.strptime(start_time, '%Y-%m-%d %H:%M:%S')
        end_time = dt.strptime(end_time, '%Y-%m-%d %H:%M:%S')

        # Find which indices in pfisr data correspond
        slices_n.append(np.argwhere((utc_time >= start_time) 
                                    & (utc_time <= end_time)))

    # Flatten pfisr array indices
    slices_n = [item[0] for sublist in slices_n for item in sublist]
    
    return slices_n

def get_isr_data(pfisr_filename, pfisr_data_dir):
    """Function to get relevant data from PFISR datafile.
    INPUT
    pfisr_filename
        type: str
        about: data file name, should be .h5 file
    pfisr_data_dir
        type: str
        about: directory where isr data is stored
    OUTPUT
    utc_time
        type: array of datetimes
        about: time stamp for the start of each measurement
    unix_time
        type: array of floats
        about: unix timestamp for start of each measurement
    pfisr_altitude
        type: array of float
        about: altitude stamp for each measurement in meters
    e_density
        type: array of float
        about: electron number density in m^-3
    de_density
        type: array of float
        about: error in number density
    """
    
    # Read in the h5 file
    pfisr_file = h5py.File(pfisr_data_dir + pfisr_filename, 'r')

    # Get the different beams and select specified angle
    beam_angle = 90
    beams = np.array(pfisr_file['BeamCodes'])

    # Get the beam with a 90 degree elevation angle
    indexes = np.linspace(0, len(beams)-1, len(beams))
    beam_num = int(indexes[np.abs(beams[:,2] - beam_angle) == 0][0])

    # Get time and convert to utc datetime
    unix_time = np.array(pfisr_file['Time']['UnixTime'])[:,0]
    utc_time = np.array([datetime.datetime.utcfromtimestamp(d) 
                         for d in unix_time])

    # Get the altitude array
    pfisr_altitude = np.array(pfisr_file['NeFromPower']
                              ['Altitude'])[beam_num, :]

    # Get the uncorrected number density array
    e_density = np.array(pfisr_file['NeFromPower']
                         ['Ne_NoTr'])[:, beam_num, :]

    # Take the transpose
    e_density = np.transpose(e_density)
    
    # Find the noise floor by averaging between 55km and 60km
    #...assume this should be zero
    
    # Calculate the power given that power = density/range^2
    pfisr_range = np.array(pfisr_file['NeFromPower']
                           ['Range'])[0, :]

    # Turn 1D array into 2D array for elementwise division
    pfisr_range = np.array([pfisr_range,]*e_density.shape[1])
    pfisr_range = np.transpose(pfisr_range)
    pfisr_power = np.divide(e_density, pfisr_range**2)

    # Get the power bias
    noise_floor = np.nanmean(pfisr_power[(pfisr_altitude > 55000)
                                    & (pfisr_altitude < 60000), :],
                              axis=0)
    
    # Only apply correction to lower altitudes
    low_fade = 90e3
    high_fade = 120e3
    correction_fade = np.ones(len(pfisr_altitude))

    # Fade from 1 to 0 over 90 to 120km
    fade_selector = (pfisr_altitude > low_fade) & (pfisr_altitude < high_fade)
    fade_len = len(fade_selector[fade_selector == True])
    fade = np.linspace(1, 0, fade_len)

    # Set correct fade values
    correction_fade[fade_selector] = fade
    correction_fade[pfisr_altitude > high_fade] = 0
    

    # Loop through each column and subtract off noise floor
    for j in range(pfisr_power.shape[1]):
        pfisr_power[:, j] = pfisr_power[:, j] - noise_floor[j]*correction_fade   

    # Calculate new unbiased density
    e_density = np.multiply(pfisr_power, pfisr_range**2)
        
    
    # Get error values
    try:
        de_density = np.array(pfisr_file['NeFromPower']
                              ['errNe_NoTr'])[:, beam_num, :]
        de_density = np.transpose(de_density)
    except:
        de_density = np.array(pfisr_file['NeFromPower']
                              ['dNeFrac'])[:, beam_num, :]
        de_density = np.transpose(de_density)
        de_density = de_density * e_density

    # Close file
    pfisr_file.close()
    
    return utc_time, unix_time, pfisr_altitude, e_density, de_density

def get_msis_density(run_time, altitude_bins, max_alt=1001e3,
                     glat=65.117, glon=212.540):
    """Function to get MSIS calculated atmospheric densities.
    DEPENDENCIES
        msise00, numpy, scipy.interpolate.interp1d
    INPUT
    run_time
        type: datetime
        about: time to run msis code for
    altitudes
        type: array of floats
        about: altitudes in meters to run msis code for
    max_alt = 1001e3
        type: float
        about: maximum altitude in meters to run msis for. 
               Function creates a high altitude log spaced array
               between the max of altitudes and the max_alt value.
               This is primarily for approximating an indefinite integral.
    OUTPUT
    total_msis_alt
        type: array of floats
        about: altitudes values in meters including original array and
               high altitude array
    msis_interp_density
        type: scipy.interplate function
        about: 1d interpolation of msis density spanning entire altitude
               range.
    """
    
    # Run msis for lower altitudes
    msis_run_low = msise00.run(time=run_time, altkm=altitude_bins/1000,
                               glat=pfrr_lat, glon=pfrr_lon)

    # Define a higher altitude array
    msis_alt_high = np.logspace(np.log10(max(altitude_bins)+1),
                                np.log10(max_alt), 20)
    
    # Run msis for these higher altitudes
    msis_run_high = msise00.run(time=run_time, altkm=msis_alt_high/1000,
                               glat=pfrr_lat, glon=pfrr_lon)

    # Get total density data
    msis_density_low = msis_run_low['Total'].data[0, :, 0, 0]
    msis_density_high = msis_run_high['Total'].data[0, :, 0, 0]

    # Combine altitude and densities from low and high altitudes
    total_msis_alt = np.concatenate((altitude_bins, msis_alt_high))
    total_msis_density = np.concatenate((msis_density_low,
                                         msis_density_high))

    # Create a scipy interpolation function to define density v. altitude
    msis_interp_density = interp1d(total_msis_alt, total_msis_density)
    
    return total_msis_alt, msis_interp_density

def isr_ion_production_rate(slice_n, alpha_type='vickrey'):
    """Function to estimate the ion production rate from isr measurements.
    There are many ways to do this that use differing chemistry
    assumptions. Vickrey 1982 is a very basic assumption for the 
    E-region and is extended to D-region. Gledhill 1986 is slightly more
    sophisticated using a best fit of many D-region measurements during
    night time aurora. Osepian 2009 is based on measurements during 
    solar proton events. The Stanford model is based on the chemistry
    model of Lehtinen 2007. 
    INPUT
    slice_n
        type: integer
        about: data slice of isr data to take
    alpha_type = 'vickrey'
        type: string
        about: what recombination coefficient to use
                other option: osepian, gledhill, stanford
    OUTPUT
    q_estimate
        type: array of float
        about: estimated ion production rate m^-2 s^-1
    dq_estimate
        type: array of float
        about: error in ion production rate
    alphas
        type: array of float
        about: recombination coefficients
    """

    if ((alpha_type=='vickrey')
        or (alpha_type=='osepian')
        or (alpha_type=='gledhill')):
        # Read in density and errors in those measurements 
        #...for specific time
        e_density_slice = e_density[:, slice_n]
        de_density_slice = de_density[:, slice_n]

        # Make interpolation model of this data with respect to altitude
        #...but only do this for altitudes > defined minimum value,
        #...below this data can be weird
        pfisr_density_interp = interp1d(pfisr_altitude, e_density_slice)

        # Same interpolation except for error in density
        pfisr_error_interp = interp1d(pfisr_altitude, de_density_slice)

        # Calculate all recombination coeffcients
        alphas = np.array([recombination_coeff(z/1000,
                                               alpha_type=alpha_type)
                           for z in altitude_bins])

        # Multiply by pfisr density to get estimate of production rate
        #...keep sign in calculation, so don't bias high
        pfisr_signs = np.sign(pfisr_density_interp(altitude_bins))
        q_estimate = (alphas 
                      * pfisr_density_interp(altitude_bins)**2)

        # Get error dq = 2*alpha*n*dn
        dq_estimate = (2 * alphas * pfisr_density_interp(altitude_bins)
                       * pfisr_error_interp(altitude_bins))
        dq_estimate = abs(dq_estimate)
    
    elif alpha_type=='stanford':
        # Read in the chemistry class
        chem = chemistry(SteadyStateTime = 100., ISRIntegrationTime = 60.)

        # Read in density and errors in those measurements
        #...for specific time
        e_density_slice = e_density[:, slice_n]
        de_density_slice = de_density[:, slice_n]

        # Make interpolation model of this data with respect to altitude
        #...but only do this for altitudes > defined minimum value,
        #...below this data can be weird
        pfisr_density_interp = interp1d(pfisr_altitude, e_density_slice)

        # Same interpolation except for error in density
        pfisr_error_interp = interp1d(pfisr_altitude, de_density_slice)

        # Multiply by pfisr density to get estimate of production rate
        #...keep sign in calculation, so don't bias high
        pfisr_signs = np.sign(pfisr_density_interp(altitude_bins))

        # Initialize ionization in chemistry class
        #...input altitude in km and stepsize of altitude bins required
        alt_step = altitude_bins[1] - altitude_bins[0]
        chem.Set_Inital_Ionization(unix_time[slice_n],
                                   pfrr_lat, pfrr_lon,
                                   min(altitude_bins)/1000,
                                   max(altitude_bins)/1000,
                                   alt_step/1000)

        # Run chemistry code to convert density to ionization rate.
        #...make sure to run initial ionziation code first
        #...input should be in km and 1/cm^3
        #...this will output in units of cgs
        q_estimate = chem.Calculate_Ionization_From_Ne(altitude_bins/1000,
                                pfisr_density_interp(altitude_bins)/1e6,
                                chem.DregionChem)

        # Add back in negatives and convert to SI
        q_estimate = q_estimate * pfisr_signs * 1e6

        # Calculate the extracted effective recombination coefficient
        alphas = q_estimate / pfisr_density_interp(altitude_bins)**2
        
        # Match Gledhill above 90 km
        e_region_cond = altitude_bins >= 90e3
        alphas[e_region_cond] = [recombination_coeff(z/1000,
                                               alpha_type='gledhill')
                                 for z in altitude_bins[e_region_cond]]
        
        # Recalculate ion production rate
        q_estimate = alphas * pfisr_density_interp(altitude_bins)**2

        # Get error dq = 2*alpha*n*dn
        dq_estimate = (2 * alphas
                       * pfisr_density_interp(altitude_bins)
                       * pfisr_error_interp(altitude_bins))
        dq_estimate = abs(dq_estimate)
        
    else:
        print('Enter good alpha type.')

    
    return q_estimate, dq_estimate, alphas

def mass_distance(z_i, I=0):
    """Function to mass distance of particle traveling some distance
    into the atmosphere. Denoted s in the derivations.
    Using trapezoid rule for this, which seems to be good enough
    INPUT
    z
        type: int
        about: index of altitude that particle reached to
    I=0
        type: float
        about: angle of magnetic inclination at measuring site in radians
    OUTPUT
    s
        type: float
        about: mass distance in kg m^-2
    """
    
    # Calculate mass distance traveled 
    s = (1/np.cos(I)) * trapezoid(total_msis_density[z_i:],
                                  total_msis_alt[z_i:])
    
    return s

def maximum_entropy_iteration(initial_num_flux, altitude_bins,
                              energy_bins,matrix_A,
                              q_estimate, dq_estimate):
    """Function to peform the maximum entropy iterative process to
    approximate inversion of matrix A. 
    Process is outlined in Semeter & Kamalabadi 2005.
    INPUT
    initial_num_flux
        type: array of float
        about: initial guess of number flux for each energy bin 
               in m^-2 s^-1
    altitude_bins
        type: array of float
        about: altitude values in meters defining altitude bins
    energy_bins
        type: array of float
        about: energy values in eV defining energy bins
    matrix_A
        type: array of float
        about: matrix that iteration is trying to invert
    q_estimate
        type: array of float
        about: estimated ion production rate from ISR m^-2 s^-1
    dq_estimate
        type: array of float
        about: error in ion production rate of ISR
    OUTPUT
    new_num_flux
        type: array of float
        about: estimated number flux for energy bins in m^-2 s^-1
    reduced_chi_square
        type: float
        about: error in modeled fit
    good_alt_index
        type: int
        about: lower than this won't be good data
    """
    
    # Set previous value to initial at start
    old_num_flux = initial_num_flux
    new_num_flux = np.zeros(len(initial_num_flux))  
    
    # Create array to store all minimum j values
    min_js = np.zeros(len(altitude_bins), dtype=int)

    # Find all nonzero indices of A matrix
    nonzero_args = np.argwhere(matrix_A > 0)

    for i in range(len(min_js)):

        non_zeros = nonzero_args[nonzero_args[:, 0] == i]

        # If there are no non zero values in row, then set to 
        #...first instance
        if len(non_zeros) == 0:
            min_js[i] = 0

        # Otherwise find the minimum j
        else:
            min_js[i] = min(non_zeros[:, 1])

    # Initialize values
    old_chi_square = 1e3
    chi_square = 0
    old_chi2_diff = 1e9
    converged = True
    count = 0

    # Run interations until convergence or count is met
    while (old_chi2_diff > convergence):

        # Check count
        if count > max_iterations:
            print('Slice: {slice_n}. '
                  'Unable to converge. '
                  'Max iterations reached with chi2 = {chi2}'
                  .format(slice_n=slice_n,
                          chi2=round(chi_square, 2)))
            break

        # Construct the t vector
        t = 1/np.dot(matrix_A[:, min_js], old_num_flux[min_js])

        # Adjust for infinite values in regions without a nonzero j
        t[t == np.inf] = 0        

        for j in range(len(energy_bins)):

            # Construct c vector
            frac = np.inner(matrix_A, old_num_flux)/q_estimate
            c = 20 * (1 - frac) * t

            # Account for nan and infinite values
            #...this is why warning is raised
            c[np.isnan(c)] = 0
            c[c == -np.inf] = 0
            c[c == np.inf] = 0

            # Define w constant
            w = np.ones(len(altitude_bins))/len(altitude_bins)

            # Summation of matrix elements
            i_sum = np.sum(w*c*matrix_A[:, j])

            # New guess
            new_num_flux[j] = old_num_flux[j]/(1-old_num_flux[j]*i_sum)

        # Check chi squared, but only on altitudes that A is defined for
        diff=q_estimate-np.dot(matrix_A, new_num_flux)
        chi_square_array = diff**2/dq_estimate**2

        # Set undefined values to zero
        chi_square_array[np.isnan(chi_square_array)] = 0
        chi_square_array[chi_square_array == np.inf] = 0
        chi_square_array[chi_square_array == -np.inf] = 0
        
        # Get the chi squared value
        chi_square = np.sum(chi_square_array)
        
        # Do a convergence test, make sure it isn't blowing up
        if (old_chi2_diff 
            < abs(old_chi_square - chi_square)) & (count > 1000):
            print('Slice: {slice_n}. '
                  'Not converging. Stopping. '
                  'chi2 = {chi2}'
                  .format(slice_n=slice_n,
                          chi2=round(chi_square, 2)))
            converged = False
            break 

        # Set old values to new
        old_num_flux = np.copy(new_num_flux)
        old_chi2_diff = abs(old_chi_square - chi_square)
        old_chi_square = chi_square

        # Set count
        count = count + 1
        
    # Get reduced chi square, which should be around 1
    diff=q_estimate-np.dot(matrix_A, new_num_flux)
    dof = len(q_estimate[dq_estimate < q_estimate]) - matrix_A.shape[1]
    
    # Notify of convergence
    if ((count < max_iterations) & (converged == True)):
        print('Slice: {slice_n}. '
              'Convergence reached. '
              'Iterations: {count}. '
              'reduced chi2: {chi2}'.format(slice_n=slice_n, 
                                            count=count-1,
                                            chi2=round(chi_square/dof, 2))
             )
        
    return new_num_flux, chi_square, dof, converged

def recombination_coeff(z, alpha_type='vickrey'):
    """Function defining recombination coefficient
    INPUT
    z
        type:float
        about: altitude in kilometers
    alpha_type = 'vickrey'
        type: string
        about: what recombination coefficient to use
                other option: osepian, gledhill
    OUTPUT
    alpha
        type: float
        about: recombination coefficient in m^3/s
    """
    
    if alpha_type == 'vickrey':
        
        alpha = 2.5e-12 * np.exp(-z/51.2)
    
    if alpha_type == 'osepian':
        
        # Read in file with effective recombination coefficient values
        alpha_filename = 'effective-recombination-coefficient.txt'
        alpha_data = np.loadtxt(alpha_filename, skiprows=6)

        # Get altitude and coeff from data
        alpha_alt = alpha_data[:, 0]
        alpha_coeff = alpha_data[:, 1]*1e-6

        # Append formula value at 144 km
        alpha_alt = np.append(alpha_alt, 144)
        alpha_coeff = np.append(alpha_coeff, recombination_coeff(144))

        # Create an interpolated function from this
        #...values outside set to 0
        alpha_interp = interp1d(alpha_alt, alpha_coeff,
                                 bounds_error=False, fill_value=0)  
        
        alpha = alpha_interp(z)
    
    if alpha_type == 'gledhill':
        
        alpha = (4.3e-6 * np.exp(-2.42e-2 * z) 
                 + 8.16e12 * np.exp(-0.524 * z))
        
        # Convert to m^3
        alpha = alpha * 1e-6
    
    return alpha

def save_inversion_density_plot(inversion_results, run_time, output_dir):
    """Function to create and save a plot of the inversion 
    electron density.
    INPUT
    inversion_results
        type: dictionary
        about: dictionary of inversion results
    run_time
        type: datetime
        about: time to create plot for
    output_dir
        type: str
        about: where to store the images
    OUTPUT
    none
    """
    # Get altitude values
    altitude_bins = inversion_results[run_time]['altitude']

    # Get measured density
    pfisr_density_plot = inversion_results[run_time]['measured_density']
    pfisr_density_plot = pfisr_density_plot

    # Initial guess
    initial_guess_plot = inversion_results[run_time]['initial_density']
    initial_guess_plot = initial_guess_plot
    
    # Finally modeled guess
    final_guess_plot = inversion_results[run_time]['modeled_density']
    final_guess_plot = final_guess_plot
    
    # Get reduced chi2
    chi2 = inversion_results[run_time]['chi2']
    dof = inversion_results[run_time]['dof']
    reduced_chi2 = chi2/dof

    # Plot figure of initial guess, real data and fit
    fig, ax = plt.subplots()

    # Titles and axis labels
    ax.set_title(str(run_time) + r' $\chi^2_{red}=$' 
                 + str(round(reduced_chi2, 2)),
                 fontsize=14, fontweight='bold')

    ax.set_ylabel('Altitude [km]', fontsize=14)
    ax.set_xlabel(r'Electron Density [m$^{-3}$]', fontsize=14)

    # Axis
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=14)

    ax.set_xscale('log')
    #ax.set_xlim(1e10, 1e12)
    #ax.set_ylim(75, 140)

    # Plot PFISR data
    ax.plot(pfisr_density_plot, altitude_bins/1000,
            color='k', linewidth=2, label = 'PFISR')

    # Plot initial guess
    ax.plot(initial_guess_plot, altitude_bins/1000,
            color='C2', linewidth=2, label = 'Initial Guess')

    # Plot final guess
    ax.plot(final_guess_plot, altitude_bins/1000,
            color='C1', linewidth=2, label = 'Final Guess')
    
    ax.plot(np.sqrt(abs(dq_estimate/alphas)), altitude_bins/1000,
            color='red')
    
    #ax.set_xlim(1e9, 1e12)

    plt.legend()

    plt.tight_layout()

    
    fig_filename = (output_dir + 'e-density-'
                    + str(run_time.date())
                    + '_' + str(run_time.hour).zfill(2)
                    + '-' + str(run_time.minute).zfill(2)
                    + '-' + str(run_time.second).zfill(2)
                    + '.jpg')
    plt.savefig(fig_filename, dpi=150)
    
    # Close the figure
    #...axis
    plt.cla()
    #...figure
    plt.clf()
    #...figure windows
    plt.close('all')
    #...clear memory
    gc.collect()

def save_inversion_numflux_plot(inversion_results, run_time, output_dir):
    """Function to create and save a plot of the inversion 
    energy spectrum.
    INPUT
    inversion_results
        type: dictionary
        about: dictionary of inversion results
    run_time
        type: datetime
        about: time to create plot for
    output_dir
        type: str
        about: where to store the images
    OUTPUT
    none
    """
    # Get energy values
    energy_bins = inversion_results[run_time]['energy_bins']
    
    # Get modeled number flux values
    num_flux = inversion_results[run_time]['modeled_flux']
    
    # Get differential number flux by multiplying by energy bin width
    bin_widths = energy_bins - np.roll(energy_bins, shift=1)
    
    # Fix first value
    bin_widths[0] = energy_bins[0] - 0
    
    num_flux = num_flux*bin_widths
    
    # Get reduced chi2
    chi2 = inversion_results[run_time]['chi2']
    dof = inversion_results[run_time]['dof']
    reduced_chi2 = chi2/dof

    # Plot figure of energy spectrum
    fig, ax = plt.subplots()

    # Titles and axis labels
    ax.set_title(str(run_time) + r' $\chi^2_{red}=$' 
                 + str(round(reduced_chi2, 2)),
                 fontsize=14, fontweight='bold')

    ax.set_ylabel(r'Number Flux [m$^{-2}$ s$^{-1}$ eV$^{-1}$]',
                  fontsize=14)
    ax.set_xlabel('Energy [eV]', fontsize=14)

    # Axis
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=14)

    ax.set_xscale('log')
    ax.set_yscale('log')

    # Plot the energy
    ax.plot(energy_bins, num_flux)

    plt.tight_layout()
    
    fig_filename = (output_dir + 'number-flux-'
                    + str(run_time.date())
                    + '_' + str(run_time.hour).zfill(2)
                    + '-' + str(run_time.minute).zfill(2)
                    + '-' + str(run_time.second).zfill(2)
                    + '.jpg')
    plt.savefig(fig_filename, dpi=150)
    
    # Close the figure
    #...axis
    plt.cla()
    #...figure
    plt.clf()
    #...figure windows
    plt.close('all')
    #...clear memory
    gc.collect()

# %%
# In[4]:


# Read in file with energy dissipation function
lambda_filename = 'semeter_kamalabadi_lambda_function.txt'
lambda_data = np.loadtxt(lambda_filename, skiprows=5)

# Create an interpolated function from this
#...values outside set to 0
lambda_interp = interp1d(lambda_data[:, 0], lambda_data[:, 1],
                         bounds_error=False, fill_value=0)

# Read in file with pulsating aurora dates, times and types
pa_database = np.loadtxt(reference_file, delimiter='\t', dtype=str)
pa_database = pa_database[1:, :]

# Convert dates to datetimes
pa_dates = np.array([dt.strptime(d, '%Y-%m-%d').date() for d 
                     in pa_database[:, 0]])


# In[5]:


for alpha_type in ['stanford']:
    
    print('Starting:', alpha_type)
    
    for pfisr_filename in pfisr_files:

        # Read in the pfisr data
        (utc_time, unix_time, 
         pfisr_altitude,
         e_density, de_density) = get_isr_data(pfisr_filename, pfisr_data_dir)

        # Find indices of interest
        slices_n = find_event_indices(utc_time)

        # Create a dictionary to store inversion results in
        inversion_results = {}

        # Make a directory to store plots and dictionary if it doesn't 
        #...already exist
        if not os.path.exists(save_dir + alpha_type + '/'):
            os.mkdir(save_dir + alpha_type + '/')

        output_dir = (save_dir + alpha_type + '/' 
                      + str(utc_time[0].date()) + '/')
        if not os.path.exists(output_dir):
            os.mkdir(output_dir)

        print(str(utc_time[0].date()))

        for slice_n in slices_n:

            run_time = utc_time[slice_n]

            # Get MSIS calculated densities
            try:
                (total_msis_alt,
                 msis_interp_density) = get_msis_density(run_time, 
                                                    altitude_bins,
                                                    max_alt=max_msis_alt,
                                                    glat=pfrr_lat,
                                                    glon=pfrr_lon)
            except Exception as e:
                print('Issue with MSIS model.', e)
                continue

            # Get density for altitude bins
            total_msis_density = msis_interp_density(total_msis_alt)
            density_rho = msis_interp_density(altitude_bins)


            # Calculate mass distance (s) for each altitude 
            #...by integrating out to 1000 km (~infinity)
            s = np.array([mass_distance(z) for z 
                          in range(len(altitude_bins))])


            # Calculate ion production rate for each energy and store
            #...in dictionary
            ion_prod_rate = {}

            for i, energy in enumerate(energy_bins):

                # Calculate range-energy value
                R = barrett_hays_range_energy_func(energy)

                # Get the (s/R)(z) for the energy
                s_R = s/R

                # Use s/R to get Lambda function values
                lambda_vals = lambda_interp(s_R)

                # Use all of this to calculate ion production rate 
                #...as function of alt
                q = (lambda_vals * density_rho * energy * F) / (35.5 * R)

                # Write to dictionary
                ion_prod_rate[energy] = q

            # Construct the A matrix
            matrix_A = np.zeros([len(altitude_bins),
                                 len(energy_bins)])

            # Loop through each energy value
            for j in range(len(energy_bins)):

                # Get the size of the energy bin
                #...first bin is from zero to energy
                if j == 0:
                    delta_E = energy_bins[j] - 0
                else:
                    delta_E = energy_bins[j] - energy_bins[j-1]

                # Set column of matrix
                matrix_A[:, j] = ion_prod_rate[energy_bins[j]]*(delta_E/F)

            # Get estimated ion production rate and error 
            #...from isr measurements
            try:
                (q_estimate, 
                 dq_estimate,
                 alphas) = isr_ion_production_rate(slice_n,
                                                   alpha_type=alpha_type)
            except:
                print('Issue with ion production rate calculation.')
                continue

            # Make an initial guess of the number flux
            initial_num_flux = estimate_initial_number_flux(energy_bins,
                                                            matrix_A)
            try:
                # Perform the maximum entropy iterative process
                (new_num_flux,
                 chi_square,
                 dof,
                 converged) = maximum_entropy_iteration(initial_num_flux,
                                                        altitude_bins,
                                                        energy_bins,
                                                        matrix_A,
                                                        q_estimate, 
                                                        dq_estimate)
            except:
                print('Issue with MEM.')
                continue

            # Write data to dictionary
            d = {'altitude' : altitude_bins,
                 'initial_density' : np.sqrt(np.dot(matrix_A,
                                                initial_num_flux)/alphas),
                 'modeled_density' : np.sqrt(np.dot(matrix_A,
                                                new_num_flux)/alphas),
                 'measured_density' : np.sqrt(q_estimate/alphas),
                 'energy_bins' : energy_bins,
                 'modeled_flux' : new_num_flux,
                 'chi2' : chi_square,
                 'dof' : dof,
                 'converged' : converged,
                 'units' : 'Values given in meters, seconds, electron-volts.'
                }

            inversion_results[run_time] = d

            # Plot the results and save to output directory
            if slice_n%1 == 0:
                save_inversion_density_plot(inversion_results,
                                            run_time, output_dir)
                save_inversion_numflux_plot(inversion_results,
                                            run_time, output_dir)

            # Clear temporary files in /dev/shm directory in Linux
            try:
                os.system('rm /dev/shm/*')
            except Exception as e: print(e)


        # Write the dictionary with inversion data to a pickle file
        with open(output_dir + 'inversion-data-' + str(utc_time[0].date()) 
                  + '.pickle', 'wb') as handle:
            pickle.dump(inversion_results, handle,
                        protocol=pickle.HIGHEST_PROTOCOL)

        print('Finished!')

    print('Finished with: ', alpha_type)
# Out:
# Starting: stanford
# 2022-03-05
# Slice: 0. Convergence reached. Iterations: 140. reduced chi2: 1.59
# Slice: 1. Convergence reached. Iterations: 145. reduced chi2: 3.78
# Slice: 2. Convergence reached. Iterations: 221. reduced chi2: 2.24
# Slice: 3. Convergence reached. Iterations: 75. reduced chi2: 3.53
# Slice: 4. Convergence reached. Iterations: 131. reduced chi2: 2.41
# Slice: 5. Convergence reached. Iterations: 123. reduced chi2: 2.4
# Slice: 6. Convergence reached. Iterations: 76. reduced chi2: 3.44
# Slice: 7. Convergence reached. Iterations: 151. reduced chi2: 1.88
# Slice: 8. Convergence reached. Iterations: 163. reduced chi2: 1.94
# Slice: 9. Convergence reached. Iterations: 118. reduced chi2: 3.17
# Slice: 10. Convergence reached. Iterations: 218. reduced chi2: 2.13
# Slice: 11. Convergence reached. Iterations: 247. reduced chi2: 2.1
# Slice: 12. Convergence reached. Iterations: 359. reduced chi2: 2.51
# Slice: 13. Convergence reached. Iterations: 349. reduced chi2: 2.28
# Slice: 14. Convergence reached. Iterations: 96. reduced chi2: 2.41
# Slice: 15. Convergence reached. Iterations: 218. reduced chi2: 1.8
# Slice: 16. Convergence reached. Iterations: 155. reduced chi2: 1.74
# Slice: 17. Convergence reached. Iterations: 293. reduced chi2: 2.4
# Slice: 18. Convergence reached. Iterations: 200. reduced chi2: 1.68
# Slice: 19. Convergence reached. Iterations: 166. reduced chi2: 3.14
# Slice: 20. Convergence reached. Iterations: 216. reduced chi2: 1.46
# Slice: 21. Convergence reached. Iterations: 170. reduced chi2: 3.36
# Slice: 22. Convergence reached. Iterations: 162. reduced chi2: 2.95
# Slice: 23. Convergence reached. Iterations: 346. reduced chi2: 5.32
# Slice: 24. Convergence reached. Iterations: 382. reduced chi2: 2.67
# Slice: 25. Convergence reached. Iterations: 146. reduced chi2: 2.17
# Slice: 26. Convergence reached. Iterations: 83. reduced chi2: 2.14
# Slice: 27. Convergence reached. Iterations: 145. reduced chi2: 2.79
# Slice: 28. Convergence reached. Iterations: 173. reduced chi2: 3.81
# Slice: 29. Convergence reached. Iterations: 140. reduced chi2: 1.81
# Slice: 30. Convergence reached. Iterations: 105. reduced chi2: 2.48
# Slice: 31. Convergence reached. Iterations: 220. reduced chi2: 2.36
# Slice: 32. Convergence reached. Iterations: 288. reduced chi2: 3.54
# Slice: 33. Convergence reached. Iterations: 227. reduced chi2: 2.51
# Slice: 34. Convergence reached. Iterations: 233. reduced chi2: 2.57
# Slice: 35. Convergence reached. Iterations: 192. reduced chi2: 2.88
# Slice: 36. Convergence reached. Iterations: 145. reduced chi2: 2.63
# Slice: 37. Convergence reached. Iterations: 457. reduced chi2: 3.19
# Slice: 38. Convergence reached. Iterations: 78. reduced chi2: 2.55
# Slice: 39. Convergence reached. Iterations: 110. reduced chi2: 2.71
# Slice: 40. Convergence reached. Iterations: 319. reduced chi2: 1.6
# Slice: 41. Convergence reached. Iterations: 189. reduced chi2: 3.72
# Slice: 42. Convergence reached. Iterations: 109. reduced chi2: 3.81
# Slice: 43. Convergence reached. Iterations: 106. reduced chi2: 3.2
# Slice: 44. Convergence reached. Iterations: 178. reduced chi2: 1.99
# Slice: 45. Convergence reached. Iterations: 271. reduced chi2: 2.07
# Slice: 46. Convergence reached. Iterations: 252. reduced chi2: 3.38
# Slice: 47. Convergence reached. Iterations: 90. reduced chi2: 1.79
# Slice: 48. Convergence reached. Iterations: 214. reduced chi2: 2.88
# Slice: 49. Convergence reached. Iterations: 270. reduced chi2: 2.08
# Slice: 50. Convergence reached. Iterations: 378. reduced chi2: 1.99
# Slice: 51. Convergence reached. Iterations: 89. reduced chi2: 0.98
# Slice: 52. Convergence reached. Iterations: 124. reduced chi2: 2.82
# Slice: 53. Convergence reached. Iterations: 158. reduced chi2: 1.31
# Slice: 54. Convergence reached. Iterations: 254. reduced chi2: 2.49
# Slice: 55. Convergence reached. Iterations: 154. reduced chi2: 1.39
# Slice: 56. Convergence reached. Iterations: 92. reduced chi2: 1.85
# Slice: 57. Convergence reached. Iterations: 364. reduced chi2: 2.31
# Slice: 58. Convergence reached. Iterations: 122. reduced chi2: 1.68
# Slice: 59. Convergence reached. Iterations: 86. reduced chi2: 2.71
# Slice: 60. Convergence reached. Iterations: 264. reduced chi2: 2.47
# Slice: 61. Convergence reached. Iterations: 256. reduced chi2: 2.02
# Slice: 62. Convergence reached. Iterations: 200. reduced chi2: 1.46
# Slice: 63. Convergence reached. Iterations: 211. reduced chi2: 1.7
# Slice: 64. Convergence reached. Iterations: 127. reduced chi2: 2.01
# Slice: 65. Convergence reached. Iterations: 275. reduced chi2: 1.9
# Slice: 66. Convergence reached. Iterations: 112. reduced chi2: 1.49
# Slice: 67. Convergence reached. Iterations: 302. reduced chi2: 2.64
# Slice: 68. Convergence reached. Iterations: 310. reduced chi2: 1.69
# Slice: 69. Convergence reached. Iterations: 167. reduced chi2: 1.55
# Slice: 70. Convergence reached. Iterations: 106. reduced chi2: 1.74
# Slice: 71. Convergence reached. Iterations: 152. reduced chi2: 1.99
# Slice: 72. Convergence reached. Iterations: 176. reduced chi2: 1.57
# Slice: 73. Convergence reached. Iterations: 67. reduced chi2: 2.04
# Slice: 74. Convergence reached. Iterations: 169. reduced chi2: 1.36
# Slice: 75. Convergence reached. Iterations: 394. reduced chi2: 1.6
# Slice: 76. Convergence reached. Iterations: 149. reduced chi2: 2.11
# Slice: 77. Convergence reached. Iterations: 258. reduced chi2: 1.74
# Slice: 78. Convergence reached. Iterations: 399. reduced chi2: 3.63
# Slice: 79. Convergence reached. Iterations: 557. reduced chi2: 2.33
# Slice: 80. Convergence reached. Iterations: 361. reduced chi2: 2.58
# Slice: 81. Convergence reached. Iterations: 435. reduced chi2: 1.86
# Slice: 82. Convergence reached. Iterations: 86. reduced chi2: 2.2
# Slice: 83. Convergence reached. Iterations: 241. reduced chi2: 2.42
# Slice: 84. Convergence reached. Iterations: 438. reduced chi2: 2.53
# Slice: 85. Convergence reached. Iterations: 209. reduced chi2: 1.42
# Slice: 86. Convergence reached. Iterations: 83. reduced chi2: 1.97
# Slice: 87. Convergence reached. Iterations: 116. reduced chi2: 1.83
# Slice: 88. Convergence reached. Iterations: 229. reduced chi2: 1.56
# Slice: 89. Convergence reached. Iterations: 258. reduced chi2: 1.61
# Slice: 90. Convergence reached. Iterations: 53. reduced chi2: 1.72
# Slice: 91. Convergence reached. Iterations: 422. reduced chi2: 1.76
# Slice: 92. Convergence reached. Iterations: 71. reduced chi2: 1.38
# Slice: 93. Convergence reached. Iterations: 187. reduced chi2: 1.86
# Slice: 94. Convergence reached. Iterations: 109. reduced chi2: 1.09
# Slice: 95. Convergence reached. Iterations: 65. reduced chi2: 2.41
# Slice: 96. Convergence reached. Iterations: 95. reduced chi2: 1.35
# Slice: 97. Convergence reached. Iterations: 124. reduced chi2: 1.39
# Slice: 98. Convergence reached. Iterations: 281. reduced chi2: 2.97
# Slice: 99. Convergence reached. Iterations: 121. reduced chi2: 2.1
# Slice: 100. Convergence reached. Iterations: 333. reduced chi2: 2.1
# Slice: 101. Convergence reached. Iterations: 303. reduced chi2: 2.33
# Slice: 102. Convergence reached. Iterations: 346. reduced chi2: 1.74
# Slice: 103. Convergence reached. Iterations: 313. reduced chi2: 2.21
# Slice: 104. Convergence reached. Iterations: 397. reduced chi2: 2.27
# Slice: 105. Convergence reached. Iterations: 128. reduced chi2: 2.24
# Slice: 106. Convergence reached. Iterations: 206. reduced chi2: 2.2
# Slice: 107. Convergence reached. Iterations: 336. reduced chi2: 2.11
# Slice: 108. Convergence reached. Iterations: 142. reduced chi2: 3.11
# Slice: 109. Convergence reached. Iterations: 62. reduced chi2: 2.25
# Slice: 110. Convergence reached. Iterations: 218. reduced chi2: 1.7
# Slice: 111. Convergence reached. Iterations: 62. reduced chi2: 1.34
# Slice: 112. Convergence reached. Iterations: 388. reduced chi2: 2.26
# Slice: 113. Convergence reached. Iterations: 322. reduced chi2: 2.41
# Slice: 114. Convergence reached. Iterations: 452. reduced chi2: 2.98
# Slice: 115. Convergence reached. Iterations: 218. reduced chi2: 2.47
# Slice: 116. Convergence reached. Iterations: 282. reduced chi2: 1.53
# Slice: 117. Convergence reached. Iterations: 268. reduced chi2: 2.08
# Slice: 118. Convergence reached. Iterations: 190. reduced chi2: 1.93
# Slice: 119. Convergence reached. Iterations: 66. reduced chi2: 1.27
# Slice: 120. Convergence reached. Iterations: 21. reduced chi2: 2.41
# Slice: 121. Convergence reached. Iterations: 331. reduced chi2: 1.73
# Slice: 122. Convergence reached. Iterations: 110. reduced chi2: 2.12
# Slice: 123. Convergence reached. Iterations: 138. reduced chi2: 1.62
# Slice: 124. Convergence reached. Iterations: 163. reduced chi2: 3.21
# Slice: 125. Convergence reached. Iterations: 121. reduced chi2: 1.41
# Slice: 126. Convergence reached. Iterations: 223. reduced chi2: 1.69
# Slice: 127. Convergence reached. Iterations: 130. reduced chi2: 1.08
# Slice: 128. Convergence reached. Iterations: 322. reduced chi2: 2.34
# Slice: 129. Convergence reached. Iterations: 155. reduced chi2: 2.37
# Slice: 130. Convergence reached. Iterations: 26. reduced chi2: 1.79
# Slice: 131. Convergence reached. Iterations: 286. reduced chi2: 2.23
# Slice: 132. Convergence reached. Iterations: 85. reduced chi2: 1.27
# Slice: 133. Convergence reached. Iterations: 379. reduced chi2: 2.1
# Slice: 134. Convergence reached. Iterations: 370. reduced chi2: 1.52
# Slice: 135. Convergence reached. Iterations: 170. reduced chi2: 1.89
# Slice: 136. Convergence reached. Iterations: 171. reduced chi2: 2.0
# Slice: 137. Convergence reached. Iterations: 493. reduced chi2: 1.71
# Slice: 138. Convergence reached. Iterations: 224. reduced chi2: 2.62
# Slice: 139. Convergence reached. Iterations: 272. reduced chi2: 1.45
# Slice: 140. Convergence reached. Iterations: 113. reduced chi2: 1.67
# Slice: 141. Convergence reached. Iterations: 401. reduced chi2: 1.46
# Slice: 142. Convergence reached. Iterations: 448. reduced chi2: 1.85
# Slice: 143. Convergence reached. Iterations: 300. reduced chi2: 0.87
# Slice: 144. Convergence reached. Iterations: 323. reduced chi2: 1.37
# Slice: 145. Convergence reached. Iterations: 228. reduced chi2: 1.24
# Slice: 146. Convergence reached. Iterations: 79. reduced chi2: 1.95
# Slice: 147. Convergence reached. Iterations: 245. reduced chi2: 1.33
# Slice: 148. Convergence reached. Iterations: 147. reduced chi2: 1.91
# Slice: 149. Convergence reached. Iterations: 53. reduced chi2: 1.28
# Slice: 150. Convergence reached. Iterations: 271. reduced chi2: 1.75
# Slice: 151. Convergence reached. Iterations: 79. reduced chi2: 2.05
# Slice: 152. Convergence reached. Iterations: 201. reduced chi2: 1.75
# Slice: 153. Convergence reached. Iterations: 53. reduced chi2: 0.88
# Slice: 154. Convergence reached. Iterations: 174. reduced chi2: 2.52
# Slice: 155. Convergence reached. Iterations: 265. reduced chi2: 2.42
# Slice: 156. Convergence reached. Iterations: 144. reduced chi2: 1.8
# Slice: 157. Convergence reached. Iterations: 89. reduced chi2: 2.45
# Slice: 158. Convergence reached. Iterations: 309. reduced chi2: 2.33
# Slice: 159. Convergence reached. Iterations: 271. reduced chi2: 1.48
# Slice: 160. Convergence reached. Iterations: 218. reduced chi2: 1.64
# Slice: 161. Convergence reached. Iterations: 205. reduced chi2: 1.69
# Slice: 162. Convergence reached. Iterations: 31. reduced chi2: 1.97
# Slice: 163. Convergence reached. Iterations: 114. reduced chi2: 1.76
# Slice: 164. Convergence reached. Iterations: 30. reduced chi2: 1.61
# Slice: 165. Convergence reached. Iterations: 39. reduced chi2: 2.18
# Slice: 166. Convergence reached. Iterations: 127. reduced chi2: 3.44
# Slice: 167. Convergence reached. Iterations: 17. reduced chi2: 4.71
# Slice: 168. Convergence reached. Iterations: 121. reduced chi2: 3.32
# Slice: 169. Convergence reached. Iterations: 157. reduced chi2: 4.65
# Slice: 170. Convergence reached. Iterations: 31. reduced chi2: 9.16
# Slice: 171. Convergence reached. Iterations: 248. reduced chi2: 4.48
# Slice: 172. Convergence reached. Iterations: 320. reduced chi2: 2.29
# Slice: 173. Convergence reached. Iterations: 79. reduced chi2: 4.37
# Slice: 174. Convergence reached. Iterations: 1493. reduced chi2: 3.77
# Slice: 175. Convergence reached. Iterations: 681. reduced chi2: 1.78
# Slice: 176. Convergence reached. Iterations: 1107. reduced chi2: 2.25
# Slice: 177. Convergence reached. Iterations: 1038. reduced chi2: 4.78
# Slice: 178. Convergence reached. Iterations: 471. reduced chi2: 1.31
# Slice: 179. Convergence reached. Iterations: 524. reduced chi2: 1.66
# Slice: 180. Convergence reached. Iterations: 330. reduced chi2: 1.82
# Slice: 181. Convergence reached. Iterations: 501. reduced chi2: 2.27
# Slice: 182. Convergence reached. Iterations: 677. reduced chi2: 1.31
# Slice: 183. Convergence reached. Iterations: 653. reduced chi2: 1.74
# Slice: 184. Convergence reached. Iterations: 859. reduced chi2: 2.49
# Slice: 185. Convergence reached. Iterations: 1667. reduced chi2: 2.9
# Slice: 186. Convergence reached. Iterations: 2341. reduced chi2: 5.22
# Slice: 187. Convergence reached. Iterations: 557. reduced chi2: 2.86
# Slice: 188. Convergence reached. Iterations: 544. reduced chi2: 2.56
# Slice: 189. Convergence reached. Iterations: 191. reduced chi2: 2.32
# Slice: 190. Convergence reached. Iterations: 1072. reduced chi2: 4.41
# Slice: 191. Convergence reached. Iterations: 1847. reduced chi2: 7.24
# Slice: 192. Convergence reached. Iterations: 812. reduced chi2: 2.06
# Slice: 193. Convergence reached. Iterations: 1989. reduced chi2: 5.01
# Slice: 194. Convergence reached. Iterations: 560. reduced chi2: 1.45
# Slice: 195. Convergence reached. Iterations: 2204. reduced chi2: 2.66
# Slice: 196. Convergence reached. Iterations: 1471. reduced chi2: 1.87
# Slice: 197. Convergence reached. Iterations: 1030. reduced chi2: 4.17
# Slice: 198. Convergence reached. Iterations: 1663. reduced chi2: 1.3
# Slice: 199. Convergence reached. Iterations: 704. reduced chi2: 1.63
# Slice: 200. Convergence reached. Iterations: 906. reduced chi2: 2.32
# Slice: 201. Convergence reached. Iterations: 412. reduced chi2: 1.78
# Slice: 202. Convergence reached. Iterations: 431. reduced chi2: 1.32
# Slice: 203. Convergence reached. Iterations: 1874. reduced chi2: 2.76
# Slice: 204. Convergence reached. Iterations: 1171. reduced chi2: 4.08
# Slice: 205. Convergence reached. Iterations: 1264. reduced chi2: 2.38
# Slice: 206. Convergence reached. Iterations: 1174. reduced chi2: 1.35
# Slice: 207. Convergence reached. Iterations: 712. reduced chi2: 1.55
# Slice: 208. Convergence reached. Iterations: 1052. reduced chi2: 1.29
# Slice: 209. Convergence reached. Iterations: 683. reduced chi2: 1.5
# Slice: 210. Convergence reached. Iterations: 793. reduced chi2: 1.46
# Slice: 211. Convergence reached. Iterations: 869. reduced chi2: 1.67
# Slice: 212. Convergence reached. Iterations: 695. reduced chi2: 1.73
# Slice: 213. Convergence reached. Iterations: 536. reduced chi2: 1.27
# Slice: 214. Convergence reached. Iterations: 687. reduced chi2: 1.51
# Slice: 215. Convergence reached. Iterations: 587. reduced chi2: 1.23
# Slice: 216. Convergence reached. Iterations: 596. reduced chi2: 1.62
# Slice: 217. Convergence reached. Iterations: 287. reduced chi2: 1.58
# Slice: 218. Convergence reached. Iterations: 525. reduced chi2: 2.47
# Slice: 219. Convergence reached. Iterations: 628. reduced chi2: 2.06
# Slice: 220. Convergence reached. Iterations: 1394. reduced chi2: 4.17
# Slice: 221. Convergence reached. Iterations: 230. reduced chi2: 1.21
# Slice: 222. Convergence reached. Iterations: 880. reduced chi2: 1.99
# Slice: 223. Convergence reached. Iterations: 375. reduced chi2: 1.22
# Slice: 224. Convergence reached. Iterations: 212. reduced chi2: 1.3
# Slice: 225. Convergence reached. Iterations: 1304. reduced chi2: 1.77
# Slice: 226. Convergence reached. Iterations: 650. reduced chi2: 1.49
# Slice: 227. Convergence reached. Iterations: 250. reduced chi2: 0.85
# Slice: 228. Convergence reached. Iterations: 542. reduced chi2: 1.45
# Slice: 229. Convergence reached. Iterations: 285. reduced chi2: 1.81
# Slice: 230. Convergence reached. Iterations: 306. reduced chi2: 2.76
# Slice: 231. Convergence reached. Iterations: 782. reduced chi2: 2.92
# Slice: 232. Convergence reached. Iterations: 456. reduced chi2: 1.53
# Slice: 233. Convergence reached. Iterations: 852. reduced chi2: 1.31
# Slice: 234. Convergence reached. Iterations: 608. reduced chi2: 0.96
# Slice: 235. Convergence reached. Iterations: 230. reduced chi2: 1.12
# Slice: 236. Convergence reached. Iterations: 377. reduced chi2: 1.58
# Slice: 237. Convergence reached. Iterations: 278. reduced chi2: 1.85
# Slice: 238. Convergence reached. Iterations: 811. reduced chi2: 1.89
# Slice: 239. Convergence reached. Iterations: 985. reduced chi2: 1.85
# Slice: 240. Convergence reached. Iterations: 841. reduced chi2: 3.85
# Slice: 241. Convergence reached. Iterations: 573. reduced chi2: 3.75
# Slice: 242. Convergence reached. Iterations: 619. reduced chi2: 1.79
# Slice: 243. Convergence reached. Iterations: 498. reduced chi2: 1.77
# Slice: 244. Convergence reached. Iterations: 980. reduced chi2: 3.4
# Slice: 245. Convergence reached. Iterations: 1363. reduced chi2: 2.36
# Slice: 246. Convergence reached. Iterations: 821. reduced chi2: 2.66
# Slice: 247. Convergence reached. Iterations: 604. reduced chi2: 1.62
# Slice: 248. Convergence reached. Iterations: 812. reduced chi2: 1.46
# Slice: 249. Convergence reached. Iterations: 1293. reduced chi2: 2.29
# Slice: 250. Convergence reached. Iterations: 1159. reduced chi2: 1.35
# Slice: 251. Convergence reached. Iterations: 1382. reduced chi2: 2.42
# Slice: 252. Convergence reached. Iterations: 999. reduced chi2: 1.81
# Slice: 253. Convergence reached. Iterations: 913. reduced chi2: 1.84
# Slice: 254. Convergence reached. Iterations: 1101. reduced chi2: 1.71
# Slice: 255. Convergence reached. Iterations: 1832. reduced chi2: 2.4
# Slice: 256. Convergence reached. Iterations: 617. reduced chi2: 1.33
# Slice: 257. Convergence reached. Iterations: 378. reduced chi2: 1.02
# Slice: 258. Convergence reached. Iterations: 404. reduced chi2: 1.22
# Slice: 259. Convergence reached. Iterations: 481. reduced chi2: 1.41
# Slice: 260. Convergence reached. Iterations: 281. reduced chi2: 1.52
# Slice: 261. Convergence reached. Iterations: 218. reduced chi2: 1.53
# Slice: 262. Convergence reached. Iterations: 163. reduced chi2: 1.46
# Slice: 263. Convergence reached. Iterations: 437. reduced chi2: 2.12
# Slice: 264. Convergence reached. Iterations: 205. reduced chi2: 1.16
# Slice: 265. Convergence reached. Iterations: 468. reduced chi2: 2.29
# Slice: 266. Convergence reached. Iterations: 957. reduced chi2: 2.21
# Slice: 267. Convergence reached. Iterations: 804. reduced chi2: 2.79
# Slice: 268. Convergence reached. Iterations: 716. reduced chi2: 1.89
# Slice: 269. Convergence reached. Iterations: 1255. reduced chi2: 2.17
# Slice: 270. Convergence reached. Iterations: 1322. reduced chi2: 1.8
# Slice: 271. Convergence reached. Iterations: 1201. reduced chi2: 2.22
# Slice: 272. Convergence reached. Iterations: 807. reduced chi2: 1.96
# Slice: 273. Convergence reached. Iterations: 634. reduced chi2: 1.38
# Slice: 274. Convergence reached. Iterations: 688. reduced chi2: 2.13
# Slice: 275. Convergence reached. Iterations: 677. reduced chi2: 1.75
# Slice: 276. Convergence reached. Iterations: 1392. reduced chi2: 1.63
# Slice: 277. Not converging. Stopping. chi2 = 157.39
# Slice: 278. Convergence reached. Iterations: 1766. reduced chi2: 45.24
# Slice: 279. Convergence reached. Iterations: 599. reduced chi2: 1.93
# Slice: 280. Convergence reached. Iterations: 373. reduced chi2: 2.71
# Slice: 281. Convergence reached. Iterations: 553. reduced chi2: 1.93
# Slice: 282. Convergence reached. Iterations: 430. reduced chi2: 1.76
# Slice: 283. Convergence reached. Iterations: 522. reduced chi2: 1.54
# Slice: 284. Convergence reached. Iterations: 323. reduced chi2: 1.2
# Slice: 285. Convergence reached. Iterations: 236. reduced chi2: 1.39
# Slice: 286. Convergence reached. Iterations: 219. reduced chi2: 1.81
# Slice: 287. Convergence reached. Iterations: 324. reduced chi2: 2.23
# Slice: 288. Convergence reached. Iterations: 263. reduced chi2: 1.6
# Slice: 289. Convergence reached. Iterations: 609. reduced chi2: 1.28
# Slice: 290. Convergence reached. Iterations: 777. reduced chi2: 2.28
# Slice: 291. Convergence reached. Iterations: 796. reduced chi2: 2.44
# Slice: 292. Convergence reached. Iterations: 941. reduced chi2: 1.26
# Slice: 293. Convergence reached. Iterations: 311. reduced chi2: 1.14
# Slice: 294. Convergence reached. Iterations: 381. reduced chi2: 1.0
# Slice: 295. Convergence reached. Iterations: 717. reduced chi2: 2.2
# Slice: 296. Convergence reached. Iterations: 399. reduced chi2: 2.24
# Slice: 297. Convergence reached. Iterations: 303. reduced chi2: 1.19
# Slice: 298. Convergence reached. Iterations: 435. reduced chi2: 1.52
# Slice: 299. Convergence reached. Iterations: 613. reduced chi2: 1.55
# Slice: 300. Convergence reached. Iterations: 436. reduced chi2: 1.39
# Slice: 301. Convergence reached. Iterations: 344. reduced chi2: 1.32
# Slice: 302. Convergence reached. Iterations: 301. reduced chi2: 1.36
# Slice: 303. Convergence reached. Iterations: 34. reduced chi2: 1.7
# Slice: 304. Convergence reached. Iterations: 32. reduced chi2: 1.59
# Slice: 305. Convergence reached. Iterations: 27. reduced chi2: 3.59
# Slice: 306. Convergence reached. Iterations: 418. reduced chi2: 2.95
# Slice: 307. Convergence reached. Iterations: 623. reduced chi2: 1.43
# Slice: 308. Convergence reached. Iterations: 679. reduced chi2: 3.14
# Slice: 309. Not converging. Stopping. chi2 = 90.09
# Slice: 310. Convergence reached. Iterations: 279. reduced chi2: 1.67
# Slice: 311. Convergence reached. Iterations: 566. reduced chi2: 1.4
# Slice: 312. Convergence reached. Iterations: 1052. reduced chi2: 3.25
# Slice: 313. Convergence reached. Iterations: 1443. reduced chi2: 1.72
# Slice: 314. Convergence reached. Iterations: 943. reduced chi2: 1.38
# Slice: 315. Convergence reached. Iterations: 1810. reduced chi2: 2.73
# Slice: 316. Convergence reached. Iterations: 1187. reduced chi2: 2.61
# Slice: 317. Convergence reached. Iterations: 898. reduced chi2: 1.97
# Slice: 318. Convergence reached. Iterations: 1136. reduced chi2: 2.32
# Slice: 319. Convergence reached. Iterations: 1005. reduced chi2: 2.04
# Slice: 320. Convergence reached. Iterations: 1508. reduced chi2: 2.42
# Slice: 321. Convergence reached. Iterations: 988. reduced chi2: 1.64
# Slice: 322. Convergence reached. Iterations: 1414. reduced chi2: 3.89
# Slice: 323. Convergence reached. Iterations: 1151. reduced chi2: 2.7
# Slice: 324. Convergence reached. Iterations: 1050. reduced chi2: 1.92
# Slice: 325. Convergence reached. Iterations: 1023. reduced chi2: 3.37
# Slice: 326. Convergence reached. Iterations: 1159. reduced chi2: 2.65
# Slice: 327. Convergence reached. Iterations: 1260. reduced chi2: 2.2
# Slice: 328. Convergence reached. Iterations: 1125. reduced chi2: 1.95
# Slice: 329. Convergence reached. Iterations: 1020. reduced chi2: 3.51
# Slice: 330. Convergence reached. Iterations: 1269. reduced chi2: 2.23
# Slice: 331. Convergence reached. Iterations: 938. reduced chi2: 2.15
# Slice: 332. Convergence reached. Iterations: 1428. reduced chi2: 2.62
# Slice: 333. Convergence reached. Iterations: 1167. reduced chi2: 2.13
# Slice: 334. Convergence reached. Iterations: 1601. reduced chi2: 3.08
# Slice: 335. Convergence reached. Iterations: 822. reduced chi2: 1.36
# Slice: 336. Convergence reached. Iterations: 1224. reduced chi2: 1.76
# Slice: 337. Convergence reached. Iterations: 1178. reduced chi2: 2.58
# Slice: 338. Convergence reached. Iterations: 1046. reduced chi2: 2.73
# Slice: 339. Convergence reached. Iterations: 1018. reduced chi2: 2.03
# Slice: 340. Convergence reached. Iterations: 1134. reduced chi2: 5.19
# Slice: 341. Convergence reached. Iterations: 1044. reduced chi2: 1.75
# Slice: 342. Convergence reached. Iterations: 613. reduced chi2: 2.14
# Slice: 343. Convergence reached. Iterations: 1589. reduced chi2: 2.52
# Slice: 344. Convergence reached. Iterations: 2111. reduced chi2: 2.91
# Slice: 345. Convergence reached. Iterations: 1978. reduced chi2: 2.73
# Slice: 346. Convergence reached. Iterations: 2696. reduced chi2: 4.38
# Slice: 347. Convergence reached. Iterations: 2245. reduced chi2: 3.15
# Slice: 348. Convergence reached. Iterations: 2789. reduced chi2: 3.55
# Slice: 349. Convergence reached. Iterations: 3646. reduced chi2: 5.79
# Slice: 350. Convergence reached. Iterations: 1648. reduced chi2: 3.61
# Slice: 351. Convergence reached. Iterations: 557. reduced chi2: 1.83
# Slice: 352. Convergence reached. Iterations: 513. reduced chi2: 1.24
# Slice: 353. Convergence reached. Iterations: 409. reduced chi2: 2.02
# Slice: 354. Convergence reached. Iterations: 1226. reduced chi2: 2.19
# Slice: 355. Convergence reached. Iterations: 1064. reduced chi2: 3.54
# Slice: 356. Convergence reached. Iterations: 571. reduced chi2: 1.62
# Slice: 357. Convergence reached. Iterations: 760. reduced chi2: 1.05
# Slice: 358. Convergence reached. Iterations: 775. reduced chi2: 2.51
# Slice: 359. Convergence reached. Iterations: 691. reduced chi2: 2.08
# Slice: 360. Convergence reached. Iterations: 518. reduced chi2: 1.62
# Slice: 361. Convergence reached. Iterations: 625. reduced chi2: 1.75
# Slice: 362. Convergence reached. Iterations: 572. reduced chi2: 1.34
# Slice: 363. Convergence reached. Iterations: 989. reduced chi2: 3.0
# Slice: 364. Convergence reached. Iterations: 756. reduced chi2: 1.95
# Slice: 365. Convergence reached. Iterations: 492. reduced chi2: 2.3
# Slice: 366. Convergence reached. Iterations: 458. reduced chi2: 1.37
# Slice: 367. Convergence reached. Iterations: 206. reduced chi2: 1.42
# Slice: 368. Convergence reached. Iterations: 327. reduced chi2: 1.75
# Slice: 369. Convergence reached. Iterations: 410. reduced chi2: 1.23
# Slice: 370. Convergence reached. Iterations: 852. reduced chi2: 1.62
# Slice: 371. Convergence reached. Iterations: 744. reduced chi2: 1.63
# Slice: 372. Convergence reached. Iterations: 425. reduced chi2: 1.85
# Slice: 373. Convergence reached. Iterations: 254. reduced chi2: 1.6
# Slice: 374. Convergence reached. Iterations: 475. reduced chi2: 1.35
# Slice: 375. Convergence reached. Iterations: 750. reduced chi2: 3.7
# Slice: 376. Convergence reached. Iterations: 715. reduced chi2: 1.95
# Slice: 377. Convergence reached. Iterations: 715. reduced chi2: 1.71
# Slice: 378. Convergence reached. Iterations: 633. reduced chi2: 2.14
# Slice: 379. Convergence reached. Iterations: 514. reduced chi2: 2.63
# Slice: 380. Convergence reached. Iterations: 612. reduced chi2: 1.96
# Slice: 381. Convergence reached. Iterations: 830. reduced chi2: 1.8
# Slice: 382. Convergence reached. Iterations: 1431. reduced chi2: 3.87
# Slice: 383. Convergence reached. Iterations: 1510. reduced chi2: 3.07
# Slice: 384. Convergence reached. Iterations: 1128. reduced chi2: 2.2
# Slice: 385. Convergence reached. Iterations: 436. reduced chi2: 1.35
# Slice: 386. Convergence reached. Iterations: 405. reduced chi2: 1.29
# Slice: 387. Convergence reached. Iterations: 479. reduced chi2: 1.17
# Slice: 388. Convergence reached. Iterations: 382. reduced chi2: 1.29
# Slice: 389. Convergence reached. Iterations: 310. reduced chi2: 1.68
# Slice: 390. Convergence reached. Iterations: 204. reduced chi2: 1.35
# Slice: 391. Convergence reached. Iterations: 423. reduced chi2: 1.23
# Slice: 392. Convergence reached. Iterations: 142. reduced chi2: 2.01
# Slice: 393. Convergence reached. Iterations: 812. reduced chi2: 1.55
# Slice: 394. Convergence reached. Iterations: 991. reduced chi2: 2.07
# Slice: 395. Convergence reached. Iterations: 534. reduced chi2: 1.45
# Slice: 396. Convergence reached. Iterations: 370. reduced chi2: 1.92
# Slice: 397. Convergence reached. Iterations: 339. reduced chi2: 1.44
# Slice: 398. Convergence reached. Iterations: 1089. reduced chi2: 2.36
# Slice: 399. Convergence reached. Iterations: 795. reduced chi2: 2.02
# Slice: 400. Convergence reached. Iterations: 939. reduced chi2: 1.91
# Slice: 401. Convergence reached. Iterations: 1110. reduced chi2: 1.87
# Slice: 402. Convergence reached. Iterations: 1091. reduced chi2: 1.63
# Slice: 403. Convergence reached. Iterations: 1143. reduced chi2: 2.16
# Slice: 404. Convergence reached. Iterations: 1360. reduced chi2: 2.86
# Slice: 405. Convergence reached. Iterations: 787. reduced chi2: 1.37
# Slice: 406. Convergence reached. Iterations: 1374. reduced chi2: 3.09
# Slice: 407. Convergence reached. Iterations: 1782. reduced chi2: 2.31
# Slice: 408. Convergence reached. Iterations: 1094. reduced chi2: 1.71
# Slice: 409. Convergence reached. Iterations: 816. reduced chi2: 1.3
# Slice: 410. Convergence reached. Iterations: 1190. reduced chi2: 1.45
# Slice: 411. Convergence reached. Iterations: 1163. reduced chi2: 2.34
# Slice: 412. Convergence reached. Iterations: 622. reduced chi2: 1.58
# Slice: 413. Convergence reached. Iterations: 1332. reduced chi2: 1.95
# Slice: 414. Convergence reached. Iterations: 1182. reduced chi2: 1.62
# Slice: 415. Convergence reached. Iterations: 990. reduced chi2: 1.88
# Slice: 416. Convergence reached. Iterations: 1391. reduced chi2: 2.08
# Slice: 417. Convergence reached. Iterations: 1399. reduced chi2: 2.12
# Slice: 418. Convergence reached. Iterations: 1376. reduced chi2: 2.95
# Slice: 419. Convergence reached. Iterations: 1129. reduced chi2: 1.6
# Slice: 420. Convergence reached. Iterations: 1248. reduced chi2: 2.81
# Slice: 421. Convergence reached. Iterations: 1062. reduced chi2: 1.19
# Slice: 422. Convergence reached. Iterations: 1203. reduced chi2: 1.75
# Slice: 423. Convergence reached. Iterations: 878. reduced chi2: 1.31
# Slice: 424. Convergence reached. Iterations: 805. reduced chi2: 2.34
# Slice: 425. Convergence reached. Iterations: 1158. reduced chi2: 1.89
# Slice: 426. Convergence reached. Iterations: 956. reduced chi2: 1.57
# Slice: 427. Convergence reached. Iterations: 675. reduced chi2: 1.35
# Slice: 428. Convergence reached. Iterations: 704. reduced chi2: 1.7
# Slice: 429. Convergence reached. Iterations: 762. reduced chi2: 1.45
# Slice: 430. Convergence reached. Iterations: 848. reduced chi2: 1.72
# Slice: 431. Convergence reached. Iterations: 1709. reduced chi2: 2.01
# Slice: 432. Convergence reached. Iterations: 945. reduced chi2: 1.5
# Slice: 433. Convergence reached. Iterations: 557. reduced chi2: 1.42
# Slice: 434. Convergence reached. Iterations: 776. reduced chi2: 2.01
# Slice: 435. Convergence reached. Iterations: 363. reduced chi2: 1.15
# Slice: 436. Convergence reached. Iterations: 159. reduced chi2: 0.72
# Slice: 437. Convergence reached. Iterations: 311. reduced chi2: 1.11
# Slice: 438. Convergence reached. Iterations: 408. reduced chi2: 1.56
# Slice: 439. Convergence reached. Iterations: 544. reduced chi2: 1.09
# Slice: 440. Convergence reached. Iterations: 515. reduced chi2: 1.71
# Slice: 441. Convergence reached. Iterations: 602. reduced chi2: 1.74
# Slice: 442. Convergence reached. Iterations: 461. reduced chi2: 1.02
# Slice: 443. Convergence reached. Iterations: 681. reduced chi2: 1.67
# Slice: 444. Convergence reached. Iterations: 340. reduced chi2: 1.76
# Slice: 445. Convergence reached. Iterations: 732. reduced chi2: 1.59
# Slice: 446. Convergence reached. Iterations: 604. reduced chi2: 1.56
# Slice: 447. Convergence reached. Iterations: 719. reduced chi2: 1.42
# Slice: 448. Convergence reached. Iterations: 947. reduced chi2: 2.31
# Slice: 449. Convergence reached. Iterations: 619. reduced chi2: 1.59
# Slice: 450. Convergence reached. Iterations: 657. reduced chi2: 1.61
# Slice: 451. Convergence reached. Iterations: 683. reduced chi2: 1.81
# Slice: 452. Convergence reached. Iterations: 501. reduced chi2: 1.54
# Slice: 453. Convergence reached. Iterations: 476. reduced chi2: 1.63
# Slice: 454. Convergence reached. Iterations: 528. reduced chi2: 1.65
# Slice: 455. Convergence reached. Iterations: 806. reduced chi2: 1.88
# Slice: 456. Convergence reached. Iterations: 1329. reduced chi2: 1.31
# Slice: 457. Convergence reached. Iterations: 896. reduced chi2: 1.42
# Slice: 458. Convergence reached. Iterations: 859. reduced chi2: 1.66
# Slice: 459. Convergence reached. Iterations: 961. reduced chi2: 2.17
# Slice: 460. Convergence reached. Iterations: 790. reduced chi2: 2.22
# Slice: 461. Convergence reached. Iterations: 733. reduced chi2: 1.28
# Slice: 462. Convergence reached. Iterations: 591. reduced chi2: 0.97
# Slice: 463. Convergence reached. Iterations: 795. reduced chi2: 1.78
# Slice: 464. Convergence reached. Iterations: 988. reduced chi2: 1.34
# Slice: 465. Convergence reached. Iterations: 601. reduced chi2: 2.52
# Slice: 466. Convergence reached. Iterations: 444. reduced chi2: 1.99
# Slice: 467. Convergence reached. Iterations: 738. reduced chi2: 1.39
# Slice: 468. Convergence reached. Iterations: 604. reduced chi2: 1.04
# Slice: 469. Convergence reached. Iterations: 692. reduced chi2: 1.22
# Slice: 470. Convergence reached. Iterations: 964. reduced chi2: 1.36
# Slice: 471. Convergence reached. Iterations: 643. reduced chi2: 1.7
# Slice: 472. Convergence reached. Iterations: 579. reduced chi2: 1.23
# Slice: 473. Convergence reached. Iterations: 518. reduced chi2: 1.61
# Slice: 474. Convergence reached. Iterations: 922. reduced chi2: 1.37
# Slice: 475. Convergence reached. Iterations: 476. reduced chi2: 1.83
# Slice: 476. Convergence reached. Iterations: 681. reduced chi2: 1.43
# Slice: 477. Convergence reached. Iterations: 386. reduced chi2: 1.26
# Slice: 478. Convergence reached. Iterations: 371. reduced chi2: 1.31
# Slice: 479. Convergence reached. Iterations: 412. reduced chi2: 1.41
# Slice: 480. Convergence reached. Iterations: 443. reduced chi2: 1.46
# Slice: 481. Convergence reached. Iterations: 562. reduced chi2: 2.09
# Slice: 482. Convergence reached. Iterations: 421. reduced chi2: 1.12
# Slice: 483. Convergence reached. Iterations: 555. reduced chi2: 1.86
# Slice: 484. Convergence reached. Iterations: 505. reduced chi2: 2.33
# Slice: 485. Convergence reached. Iterations: 571. reduced chi2: 1.74
# Slice: 486. Convergence reached. Iterations: 534. reduced chi2: 1.61
# Slice: 487. Convergence reached. Iterations: 362. reduced chi2: 1.46
# Slice: 488. Convergence reached. Iterations: 642. reduced chi2: 1.97
# Slice: 489. Convergence reached. Iterations: 890. reduced chi2: 1.36
# Slice: 490. Convergence reached. Iterations: 584. reduced chi2: 1.37
# Slice: 491. Convergence reached. Iterations: 572. reduced chi2: 1.29
# Slice: 492. Convergence reached. Iterations: 364. reduced chi2: 2.16
# Slice: 493. Convergence reached. Iterations: 811. reduced chi2: 1.23
# Slice: 494. Convergence reached. Iterations: 702. reduced chi2: 1.33
# Slice: 495. Convergence reached. Iterations: 910. reduced chi2: 1.6
# Slice: 496. Convergence reached. Iterations: 936. reduced chi2: 1.41
# Slice: 497. Convergence reached. Iterations: 1120. reduced chi2: 1.46
# Slice: 498. Convergence reached. Iterations: 1157. reduced chi2: 1.88
# Slice: 499. Convergence reached. Iterations: 849. reduced chi2: 1.39
# Slice: 500. Convergence reached. Iterations: 865. reduced chi2: 1.76
# Slice: 501. Convergence reached. Iterations: 1004. reduced chi2: 1.12
# Slice: 502. Convergence reached. Iterations: 522. reduced chi2: 1.94
# Slice: 503. Convergence reached. Iterations: 1204. reduced chi2: 2.8
# Slice: 504. Convergence reached. Iterations: 973. reduced chi2: 2.64
# Slice: 505. Convergence reached. Iterations: 989. reduced chi2: 1.06
# Slice: 506. Convergence reached. Iterations: 1027. reduced chi2: 1.33
# Slice: 507. Convergence reached. Iterations: 709. reduced chi2: 1.66
# Slice: 508. Convergence reached. Iterations: 1298. reduced chi2: 1.38
# Slice: 509. Convergence reached. Iterations: 1473. reduced chi2: 1.74
# Slice: 510. Convergence reached. Iterations: 849. reduced chi2: 1.87
# Slice: 511. Convergence reached. Iterations: 790. reduced chi2: 1.35
# Slice: 512. Convergence reached. Iterations: 811. reduced chi2: 2.38
# Slice: 513. Convergence reached. Iterations: 405. reduced chi2: 1.57
# Slice: 514. Convergence reached. Iterations: 588. reduced chi2: 1.46
# Slice: 515. Convergence reached. Iterations: 623. reduced chi2: 1.37
# Slice: 516. Convergence reached. Iterations: 1039. reduced chi2: 3.69
# Slice: 517. Convergence reached. Iterations: 1158. reduced chi2: 2.0
# Slice: 518. Convergence reached. Iterations: 1286. reduced chi2: 2.67
# Slice: 519. Convergence reached. Iterations: 916. reduced chi2: 1.8
# Slice: 520. Convergence reached. Iterations: 848. reduced chi2: 1.1
# Slice: 521. Convergence reached. Iterations: 1086. reduced chi2: 1.62
# Slice: 522. Convergence reached. Iterations: 1090. reduced chi2: 2.2
# Slice: 523. Convergence reached. Iterations: 306. reduced chi2: 1.47
# Slice: 524. Convergence reached. Iterations: 178. reduced chi2: 1.16
# Slice: 525. Convergence reached. Iterations: 466. reduced chi2: 1.34
# Slice: 526. Convergence reached. Iterations: 716. reduced chi2: 1.9
# Slice: 527. Convergence reached. Iterations: 1097. reduced chi2: 2.09
# Slice: 528. Convergence reached. Iterations: 987. reduced chi2: 2.35
# Slice: 529. Convergence reached. Iterations: 574. reduced chi2: 1.81
# Slice: 530. Convergence reached. Iterations: 556. reduced chi2: 1.57
# Slice: 531. Convergence reached. Iterations: 420. reduced chi2: 1.44
# Slice: 532. Convergence reached. Iterations: 764. reduced chi2: 1.99
# Slice: 533. Convergence reached. Iterations: 717. reduced chi2: 1.24
# Slice: 534. Convergence reached. Iterations: 1405. reduced chi2: 3.12
# Slice: 535. Convergence reached. Iterations: 746. reduced chi2: 1.34
# Slice: 536. Convergence reached. Iterations: 1708. reduced chi2: 2.11
# Slice: 537. Convergence reached. Iterations: 1491. reduced chi2: 2.57
# Slice: 538. Convergence reached. Iterations: 1559. reduced chi2: 1.51
# Slice: 539. Convergence reached. Iterations: 1075. reduced chi2: 1.68
# Slice: 540. Convergence reached. Iterations: 787. reduced chi2: 1.55
# Slice: 541. Convergence reached. Iterations: 440. reduced chi2: 2.09
# Slice: 542. Convergence reached. Iterations: 885. reduced chi2: 1.66
# Slice: 543. Convergence reached. Iterations: 897. reduced chi2: 2.07
# Slice: 544. Convergence reached. Iterations: 449. reduced chi2: 2.16
# Slice: 545. Convergence reached. Iterations: 1472. reduced chi2: 2.77
# Slice: 546. Convergence reached. Iterations: 1145. reduced chi2: 2.44
# Slice: 547. Convergence reached. Iterations: 1036. reduced chi2: 2.15
# Slice: 548. Convergence reached. Iterations: 1058. reduced chi2: 2.61
# Slice: 549. Convergence reached. Iterations: 1143. reduced chi2: 2.84
# Slice: 550. Convergence reached. Iterations: 706. reduced chi2: 1.99
# Slice: 551. Convergence reached. Iterations: 257. reduced chi2: 1.12
# Slice: 552. Convergence reached. Iterations: 601. reduced chi2: 2.04
# Slice: 553. Convergence reached. Iterations: 630. reduced chi2: 3.87
# Slice: 554. Convergence reached. Iterations: 1865. reduced chi2: 2.77
# Slice: 555. Convergence reached. Iterations: 675. reduced chi2: 2.22
# Slice: 556. Convergence reached. Iterations: 931. reduced chi2: 2.44
# Slice: 557. Convergence reached. Iterations: 514. reduced chi2: 1.37
# Slice: 558. Convergence reached. Iterations: 828. reduced chi2: 1.54
# Slice: 559. Convergence reached. Iterations: 1921. reduced chi2: 2.49
# Slice: 560. Convergence reached. Iterations: 694. reduced chi2: 1.35
# Slice: 561. Convergence reached. Iterations: 599. reduced chi2: 1.45
# Slice: 562. Convergence reached. Iterations: 745. reduced chi2: 1.26
# Slice: 563. Convergence reached. Iterations: 948. reduced chi2: 1.74
# Slice: 564. Convergence reached. Iterations: 1271. reduced chi2: 6.46
# Slice: 565. Convergence reached. Iterations: 330. reduced chi2: 1.57
# Slice: 566. Convergence reached. Iterations: 878. reduced chi2: 3.35
# Slice: 567. Convergence reached. Iterations: 1598. reduced chi2: 2.48
# Slice: 568. Convergence reached. Iterations: 535. reduced chi2: 2.8
# Slice: 569. Convergence reached. Iterations: 380. reduced chi2: 1.51
# Slice: 570. Convergence reached. Iterations: 819. reduced chi2: 1.24
# Slice: 571. Convergence reached. Iterations: 740. reduced chi2: 1.79
# Slice: 572. Convergence reached. Iterations: 895. reduced chi2: 2.02
# Slice: 573. Convergence reached. Iterations: 653. reduced chi2: 1.49
# Slice: 574. Convergence reached. Iterations: 550. reduced chi2: 1.43
# Slice: 575. Convergence reached. Iterations: 301. reduced chi2: 1.29
# Slice: 576. Convergence reached. Iterations: 370. reduced chi2: 1.64
# Slice: 577. Convergence reached. Iterations: 1325. reduced chi2: 2.45
# Slice: 578. Convergence reached. Iterations: 1643. reduced chi2: 2.59
# Slice: 579. Convergence reached. Iterations: 1409. reduced chi2: 2.25
# Slice: 580. Convergence reached. Iterations: 1091. reduced chi2: 1.27
# Slice: 581. Convergence reached. Iterations: 1226. reduced chi2: 1.65
# Slice: 582. Convergence reached. Iterations: 886. reduced chi2: 1.14
# Slice: 583. Convergence reached. Iterations: 1052. reduced chi2: 0.99
# Slice: 584. Convergence reached. Iterations: 1121. reduced chi2: 1.34
# Slice: 585. Convergence reached. Iterations: 1594. reduced chi2: 1.69
# Slice: 586. Convergence reached. Iterations: 1506. reduced chi2: 1.41
# Slice: 587. Convergence reached. Iterations: 1190. reduced chi2: 0.96
# Slice: 588. Convergence reached. Iterations: 851. reduced chi2: 1.37
# Slice: 589. Convergence reached. Iterations: 756. reduced chi2: 0.83
# Slice: 590. Convergence reached. Iterations: 1041. reduced chi2: 1.52
# Slice: 591. Convergence reached. Iterations: 1512. reduced chi2: 1.75
# Slice: 592. Convergence reached. Iterations: 773. reduced chi2: 3.39
# Slice: 593. Convergence reached. Iterations: 771. reduced chi2: 1.61
# Slice: 594. Convergence reached. Iterations: 172. reduced chi2: 0.89
# Slice: 595. Convergence reached. Iterations: 479. reduced chi2: 1.26
# Slice: 596. Convergence reached. Iterations: 1404. reduced chi2: 1.7
# Slice: 597. Convergence reached. Iterations: 871. reduced chi2: 1.38
# Slice: 598. Convergence reached. Iterations: 1113. reduced chi2: 1.75
# Slice: 599. Convergence reached. Iterations: 778. reduced chi2: 1.23
# Slice: 600. Convergence reached. Iterations: 786. reduced chi2: 2.12
# Slice: 601. Convergence reached. Iterations: 570. reduced chi2: 2.61
# Slice: 602. Convergence reached. Iterations: 430. reduced chi2: 1.27
# Slice: 603. Convergence reached. Iterations: 459. reduced chi2: 1.49
# Slice: 604. Convergence reached. Iterations: 598. reduced chi2: 1.7
# Slice: 605. Convergence reached. Iterations: 596. reduced chi2: 1.4
# Slice: 606. Convergence reached. Iterations: 374. reduced chi2: 1.23
# Slice: 607. Convergence reached. Iterations: 522. reduced chi2: 0.96
# Slice: 608. Convergence reached. Iterations: 1260. reduced chi2: 2.24
# Slice: 609. Convergence reached. Iterations: 687. reduced chi2: 1.63
# Slice: 610. Convergence reached. Iterations: 1222. reduced chi2: 1.26
# Slice: 611. Convergence reached. Iterations: 575. reduced chi2: 1.77
# Slice: 612. Convergence reached. Iterations: 564. reduced chi2: 1.73
# Slice: 613. Convergence reached. Iterations: 851. reduced chi2: 1.66
# Slice: 614. Convergence reached. Iterations: 469. reduced chi2: 1.29
# Slice: 615. Convergence reached. Iterations: 472. reduced chi2: 1.09
# Slice: 616. Convergence reached. Iterations: 476. reduced chi2: 1.36
# Slice: 617. Convergence reached. Iterations: 361. reduced chi2: 0.89
# Slice: 618. Convergence reached. Iterations: 171. reduced chi2: 1.17
# Slice: 619. Convergence reached. Iterations: 381. reduced chi2: 1.08
# Slice: 620. Convergence reached. Iterations: 315. reduced chi2: 1.09
# Slice: 621. Convergence reached. Iterations: 179. reduced chi2: 1.22
# Slice: 622. Convergence reached. Iterations: 204. reduced chi2: 1.59
# Slice: 623. Convergence reached. Iterations: 443. reduced chi2: 1.11
# Slice: 624. Convergence reached. Iterations: 550. reduced chi2: 1.38
# Slice: 625. Convergence reached. Iterations: 650. reduced chi2: 0.98
# Slice: 626. Convergence reached. Iterations: 919. reduced chi2: 1.55
# Slice: 627. Convergence reached. Iterations: 1009. reduced chi2: 1.47
# Slice: 628. Convergence reached. Iterations: 263. reduced chi2: 1.36
# Slice: 629. Convergence reached. Iterations: 799. reduced chi2: 1.48
# Slice: 630. Convergence reached. Iterations: 434. reduced chi2: 1.28
# Slice: 631. Convergence reached. Iterations: 610. reduced chi2: 1.27
# Slice: 632. Convergence reached. Iterations: 966. reduced chi2: 1.6
# Slice: 633. Convergence reached. Iterations: 696. reduced chi2: 1.1
# Slice: 634. Convergence reached. Iterations: 499. reduced chi2: 1.56
# Slice: 635. Convergence reached. Iterations: 486. reduced chi2: 0.95
# Slice: 636. Convergence reached. Iterations: 973. reduced chi2: 1.92
# Slice: 637. Convergence reached. Iterations: 938. reduced chi2: 1.53
# Slice: 638. Convergence reached. Iterations: 581. reduced chi2: 1.61
# Slice: 639. Convergence reached. Iterations: 559. reduced chi2: 0.98
# Slice: 640. Convergence reached. Iterations: 463. reduced chi2: 1.04
# Slice: 641. Convergence reached. Iterations: 352. reduced chi2: 0.92
# Slice: 642. Convergence reached. Iterations: 441. reduced chi2: 1.21
# Slice: 643. Convergence reached. Iterations: 300. reduced chi2: 1.67
# Slice: 644. Convergence reached. Iterations: 208. reduced chi2: 1.02
# Slice: 645. Convergence reached. Iterations: 366. reduced chi2: 1.5
# Slice: 646. Convergence reached. Iterations: 507. reduced chi2: 2.54
# Slice: 647. Convergence reached. Iterations: 671. reduced chi2: 1.37
# Slice: 648. Convergence reached. Iterations: 663. reduced chi2: 1.22
# Slice: 649. Convergence reached. Iterations: 314. reduced chi2: 1.38
# Slice: 650. Convergence reached. Iterations: 300. reduced chi2: 1.02
# Slice: 651. Convergence reached. Iterations: 601. reduced chi2: 1.7
# Slice: 652. Convergence reached. Iterations: 702. reduced chi2: 1.54
# Slice: 653. Convergence reached. Iterations: 678. reduced chi2: 1.47
# Slice: 654. Convergence reached. Iterations: 580. reduced chi2: 1.63
# Slice: 655. Convergence reached. Iterations: 1026. reduced chi2: 1.49
# Slice: 656. Convergence reached. Iterations: 333. reduced chi2: 1.2
# Slice: 657. Convergence reached. Iterations: 454. reduced chi2: 1.34
# Slice: 658. Convergence reached. Iterations: 666. reduced chi2: 1.74
# Slice: 659. Convergence reached. Iterations: 503. reduced chi2: 1.25
# Slice: 660. Convergence reached. Iterations: 577. reduced chi2: 1.6
# Slice: 661. Convergence reached. Iterations: 541. reduced chi2: 1.45
# Slice: 662. Convergence reached. Iterations: 390. reduced chi2: 1.35
# Slice: 663. Convergence reached. Iterations: 334. reduced chi2: 1.11
# Slice: 664. Convergence reached. Iterations: 570. reduced chi2: 1.52
# Slice: 665. Convergence reached. Iterations: 644. reduced chi2: 1.92
# Slice: 666. Convergence reached. Iterations: 432. reduced chi2: 1.04
# Slice: 667. Convergence reached. Iterations: 992. reduced chi2: 1.44
# Slice: 668. Convergence reached. Iterations: 681. reduced chi2: 2.02
# Slice: 669. Convergence reached. Iterations: 662. reduced chi2: 0.94
# Slice: 670. Convergence reached. Iterations: 1028. reduced chi2: 1.23
# Slice: 671. Convergence reached. Iterations: 763. reduced chi2: 0.85
# Slice: 672. Convergence reached. Iterations: 749. reduced chi2: 1.05
# Slice: 673. Convergence reached. Iterations: 602. reduced chi2: 1.48
# Slice: 674. Convergence reached. Iterations: 697. reduced chi2: 1.12
# Slice: 675. Convergence reached. Iterations: 481. reduced chi2: 1.29
# Slice: 676. Convergence reached. Iterations: 531. reduced chi2: 1.12
# Slice: 677. Convergence reached. Iterations: 330. reduced chi2: 0.97
# Slice: 678. Convergence reached. Iterations: 542. reduced chi2: 1.43
# Slice: 679. Convergence reached. Iterations: 684. reduced chi2: 1.47
# Slice: 680. Convergence reached. Iterations: 617. reduced chi2: 1.15
# Slice: 681. Convergence reached. Iterations: 732. reduced chi2: 1.56
# Slice: 682. Convergence reached. Iterations: 593. reduced chi2: 1.08
# Slice: 683. Convergence reached. Iterations: 854. reduced chi2: 1.63
# Slice: 684. Convergence reached. Iterations: 524. reduced chi2: 0.94
# Slice: 685. Convergence reached. Iterations: 635. reduced chi2: 0.85
# Slice: 686. Convergence reached. Iterations: 482. reduced chi2: 1.33
# Slice: 687. Convergence reached. Iterations: 911. reduced chi2: 1.41
# Slice: 688. Convergence reached. Iterations: 497. reduced chi2: 1.22
# Slice: 689. Convergence reached. Iterations: 375. reduced chi2: 1.48
# Slice: 690. Convergence reached. Iterations: 861. reduced chi2: 1.24
# Slice: 691. Convergence reached. Iterations: 397. reduced chi2: 1.97
# Slice: 692. Convergence reached. Iterations: 343. reduced chi2: 1.19
# Slice: 693. Convergence reached. Iterations: 362. reduced chi2: 1.11
# Slice: 694. Convergence reached. Iterations: 389. reduced chi2: 1.42
# Slice: 695. Convergence reached. Iterations: 272. reduced chi2: 1.27
# Slice: 696. Convergence reached. Iterations: 257. reduced chi2: 1.18
# Slice: 697. Convergence reached. Iterations: 673. reduced chi2: 1.06
# Slice: 698. Convergence reached. Iterations: 426. reduced chi2: 0.99
# Slice: 699. Convergence reached. Iterations: 532. reduced chi2: 1.81
# Slice: 700. Convergence reached. Iterations: 201. reduced chi2: 1.25
# Slice: 701. Convergence reached. Iterations: 414. reduced chi2: 1.36
# Slice: 702. Convergence reached. Iterations: 397. reduced chi2: 1.04
# Slice: 703. Convergence reached. Iterations: 310. reduced chi2: 1.01
# Slice: 704. Convergence reached. Iterations: 695. reduced chi2: 1.01
# Slice: 705. Convergence reached. Iterations: 584. reduced chi2: 1.14
# Slice: 706. Convergence reached. Iterations: 220. reduced chi2: 0.98
# Slice: 707. Convergence reached. Iterations: 285. reduced chi2: 1.15
# Slice: 708. Convergence reached. Iterations: 251. reduced chi2: 1.08
# Slice: 709. Convergence reached. Iterations: 580. reduced chi2: 2.27
# Slice: 710. Convergence reached. Iterations: 397. reduced chi2: 1.08
# Slice: 711. Convergence reached. Iterations: 637. reduced chi2: 1.17
# Slice: 712. Convergence reached. Iterations: 462. reduced chi2: 1.34
# Slice: 713. Convergence reached. Iterations: 591. reduced chi2: 1.64
# Slice: 714. Convergence reached. Iterations: 411. reduced chi2: 1.36
# Slice: 715. Convergence reached. Iterations: 806. reduced chi2: 1.28
# Slice: 716. Convergence reached. Iterations: 662. reduced chi2: 1.28
# Slice: 717. Convergence reached. Iterations: 561. reduced chi2: 1.33
# Slice: 718. Convergence reached. Iterations: 546. reduced chi2: 0.8
# Slice: 719. Convergence reached. Iterations: 538. reduced chi2: 1.24
# Slice: 720. Convergence reached. Iterations: 493. reduced chi2: 1.75
# Slice: 721. Convergence reached. Iterations: 420. reduced chi2: 1.08
# Slice: 722. Convergence reached. Iterations: 182. reduced chi2: 0.89
# Slice: 723. Convergence reached. Iterations: 296. reduced chi2: 1.15
# Slice: 724. Convergence reached. Iterations: 742. reduced chi2: 1.12
# Slice: 725. Convergence reached. Iterations: 301. reduced chi2: 0.77
# Slice: 726. Convergence reached. Iterations: 202. reduced chi2: 1.34
# Slice: 727. Convergence reached. Iterations: 447. reduced chi2: 0.97
# Slice: 728. Convergence reached. Iterations: 160. reduced chi2: 1.14
# Slice: 729. Convergence reached. Iterations: 259. reduced chi2: 1.34
# Slice: 730. Convergence reached. Iterations: 504. reduced chi2: 0.82
# Slice: 731. Convergence reached. Iterations: 388. reduced chi2: 1.27
# Slice: 732. Convergence reached. Iterations: 270. reduced chi2: 1.04
# Slice: 733. Convergence reached. Iterations: 1017. reduced chi2: 1.99
# Slice: 734. Convergence reached. Iterations: 1081. reduced chi2: 1.84
# Slice: 735. Convergence reached. Iterations: 527. reduced chi2: 1.06
# Slice: 736. Convergence reached. Iterations: 732. reduced chi2: 2.02
# Slice: 737. Convergence reached. Iterations: 533. reduced chi2: 1.34
# Slice: 738. Convergence reached. Iterations: 396. reduced chi2: 1.73
# Slice: 739. Convergence reached. Iterations: 894. reduced chi2: 1.47
# Slice: 740. Convergence reached. Iterations: 674. reduced chi2: 1.13
# Slice: 741. Convergence reached. Iterations: 759. reduced chi2: 1.89
# Slice: 742. Convergence reached. Iterations: 353. reduced chi2: 0.97
# Slice: 743. Convergence reached. Iterations: 587. reduced chi2: 1.23
# Slice: 744. Convergence reached. Iterations: 397. reduced chi2: 1.24
# Slice: 745. Convergence reached. Iterations: 172. reduced chi2: 1.07
# Slice: 746. Convergence reached. Iterations: 540. reduced chi2: 1.24
# Slice: 747. Convergence reached. Iterations: 404. reduced chi2: 1.61
# Slice: 748. Convergence reached. Iterations: 234. reduced chi2: 1.27
# Slice: 749. Convergence reached. Iterations: 233. reduced chi2: 2.24
# Slice: 750. Convergence reached. Iterations: 471. reduced chi2: 1.88
# Slice: 751. Convergence reached. Iterations: 428. reduced chi2: 1.07
# Slice: 752. Convergence reached. Iterations: 650. reduced chi2: 1.23
# Slice: 753. Convergence reached. Iterations: 645. reduced chi2: 1.23
# Slice: 754. Convergence reached. Iterations: 501. reduced chi2: 1.31
# Slice: 755. Convergence reached. Iterations: 218. reduced chi2: 0.69
# Finished!
# Finished with:  stanford
